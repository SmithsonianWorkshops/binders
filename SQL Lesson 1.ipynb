# %% [markdown]
# Roughly following along with this lesson from Data Management with SQL for Ecologists: https://datacarpentry.org/sql-ecology-lesson/01-sql-basic-queries/index.html

# %%
%LOAD portal_mammals.sqlite

# %%
SELECT year
FROM surveys LIMIT 10;
# Out:
# +------+
# | year |
# +------+
# | 1977 |
# +------+
# | 1977 |
# +------+
# | 1977 |
# +------+
# | 1977 |
# +------+
# | 1977 |
# +------+
# | 1977 |
# +------+
# | 1977 |
# +------+
# | 1977 |
# +------+
# | 1977 |
# +------+
# | 1977 |
# +------+

# %%
SELECT year, month, day
FROM surveys LIMIT 10;
# Out:
# +------+-------+-----+
# | year | month | day |
# +------+-------+-----+
# | 1977 | 7     | 16  |
# +------+-------+-----+
# | 1977 | 7     | 16  |
# +------+-------+-----+
# | 1977 | 7     | 16  |
# +------+-------+-----+
# | 1977 | 7     | 16  |
# +------+-------+-----+
# | 1977 | 7     | 16  |
# +------+-------+-----+
# | 1977 | 7     | 16  |
# +------+-------+-----+
# | 1977 | 7     | 16  |
# +------+-------+-----+
# | 1977 | 7     | 16  |
# +------+-------+-----+
# | 1977 | 7     | 16  |
# +------+-------+-----+
# | 1977 | 7     | 16  |
# +------+-------+-----+

# %%
SELECT *
FROM surveys
LIMIT 10;
# Out:
# +-----------+-------+-----+------+---------+------------+-----+-----------------+--------+
# | record_id | month | day | year | plot_id | species_id | sex | hindfoot_length | weight |
# +-----------+-------+-----+------+---------+------------+-----+-----------------+--------+
# | 1         | 7     | 16  | 1977 | 2       | NL         | M   | 32.0            |        |
# +-----------+-------+-----+------+---------+------------+-----+-----------------+--------+
# | 2         | 7     | 16  | 1977 | 3       | NL         | M   | 33.0            |        |
# +-----------+-------+-----+------+---------+------------+-----+-----------------+--------+
# | 3         | 7     | 16  | 1977 | 2       | DM         | F   | 37.0            |        |
# +-----------+-------+-----+------+---------+------------+-----+-----------------+--------+
# | 4         | 7     | 16  | 1977 | 7       | DM         | M   | 36.0            |        |
# ...
